# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hcd=pd.read_csv("Health_Camp_Detail.csv")
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  Category3
# 0            6560       16-Aug-03     20-Aug-03     First         B          2
# 1            6530       16-Aug-03     28-Oct-03     First         C          2
# 2            6544       03-Nov-03     15-Nov-03     First         F          1
# 3            6585       22-Nov-03     05-Dec-03     First         E          2
# 4            6561       30-Nov-03     18-Dec-03     First         E          1

# %%
hcd['Camp_Start_Date']=pd.to_datetime(hcd['Camp_Start_Date'])

# %%
hcd['Camp_End_Date']=pd.to_datetime(hcd['Camp_End_Date'])

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  Category3
# 0            6560      2003-08-16    2003-08-20     First         B          2
# 1            6530      2003-08-16    2003-10-28     First         C          2
# 2            6544      2003-11-03    2003-11-15     First         F          1
# 3            6585      2003-11-22    2003-12-05     First         E          2
# 4            6561      2003-11-30    2003-12-18     First         E          1

# %%
hcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Health_Camp_ID   65 non-null     int64
#  1   Camp_Start_Date  65 non-null     datetime64[ns]
#  2   Camp_End_Date    65 non-null     datetime64[ns]
#  3   Category1        65 non-null     object
#  4   Category2        65 non-null     object
#  5   Category3        65 non-null     int64
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 3.2+ KB

# %%
hcd['Category1']=hcd['Category1']+"_cat1"

# %%
hcd['Category2']=hcd['Category2']+"_cat2"

# %%
hcd['Category3']=hcd['Category3'].apply(lambda x:str(x))+'_cat3'

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date   Category1 Category2  \
# 0            6560      2003-08-16    2003-08-20  First_cat1    B_cat2
# 1            6530      2003-08-16    2003-10-28  First_cat1    C_cat2
# 2            6544      2003-11-03    2003-11-15  First_cat1    F_cat2
# 3            6585      2003-11-22    2003-12-05  First_cat1    E_cat2
# 4            6561      2003-11-30    2003-12-18  First_cat1    E_cat2
#
#   Category3
# 0    2_cat3
# 1    2_cat3
# 2    1_cat3
# 3    2_cat3
# 4    1_cat3

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date   Category1 Category2  \
# 0            6560      2003-08-16    2003-08-20  First_cat1    B_cat2
# 1            6530      2003-08-16    2003-10-28  First_cat1    C_cat2
# 2            6544      2003-11-03    2003-11-15  First_cat1    F_cat2
# 3            6585      2003-11-22    2003-12-05  First_cat1    E_cat2
# 4            6561      2003-11-30    2003-12-18  First_cat1    E_cat2
#
#   Category3
# 0    2_cat3
# 1    2_cat3
# 2    1_cat3
# 3    2_cat3
# 4    1_cat3

# %%
hcd['Camp_duration']=(hcd['Camp_End_Date']-hcd['Camp_Start_Date']).astype('timedelta64[D]')

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date   Category1 Category2  \
# 0            6560      2003-08-16    2003-08-20  First_cat1    B_cat2
# 1            6530      2003-08-16    2003-10-28  First_cat1    C_cat2
# 2            6544      2003-11-03    2003-11-15  First_cat1    F_cat2
# 3            6585      2003-11-22    2003-12-05  First_cat1    E_cat2
# 4            6561      2003-11-30    2003-12-18  First_cat1    E_cat2
#
#   Category3  Camp_duration
# 0    2_cat3            4.0
# 1    2_cat3           73.0
# 2    1_cat3           12.0
# 3    2_cat3           13.0
# 4    1_cat3           18.0

# %%
hcd['Camp_start_Day']=hcd['Camp_Start_Date'].apply(lambda x:x.dayofweek)

# %%
hcd['Camp_start_Month']=hcd['Camp_Start_Date'].apply(lambda x:x.month)

# %%
hcd['Camp_start_Year']=hcd['Camp_Start_Date'].apply(lambda x:x.year)

# %%
hcd['Camp_End_Day']=hcd['Camp_End_Date'].apply(lambda x:x.dayofweek)
hcd['Camp_End_Month']=hcd['Camp_End_Date'].apply(lambda x:x.month)
hcd['Camp_End_Year']=hcd['Camp_End_Date'].apply(lambda x:x.year)

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date   Category1 Category2  \
# 0            6560      2003-08-16    2003-08-20  First_cat1    B_cat2
# 1            6530      2003-08-16    2003-10-28  First_cat1    C_cat2
# 2            6544      2003-11-03    2003-11-15  First_cat1    F_cat2
# 3            6585      2003-11-22    2003-12-05  First_cat1    E_cat2
# 4            6561      2003-11-30    2003-12-18  First_cat1    E_cat2
#
#   Category3  Camp_duration  Camp_start_Day  Camp_start_Month  Camp_start_Year  \
# 0    2_cat3            4.0               5                 8             2003
# 1    2_cat3           73.0               5                 8             2003
# 2    1_cat3           12.0               0                11             2003
# 3    2_cat3           13.0               5                11             2003
# 4    1_cat3           18.0               6                11             2003
#
#    Camp_End_Day  Camp_End_Month  Camp_End_Year
# ...

# %%
hcd['weekends_during_campaign']=[pd.date_range(x,y).weekday.isin([5,6]).sum() for x , y in zip(hcd['Camp_Start_Date'],hcd['Camp_End_Date'])]

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date   Category1 Category2  \
# 0            6560      2003-08-16    2003-08-20  First_cat1    B_cat2
# 1            6530      2003-08-16    2003-10-28  First_cat1    C_cat2
# 2            6544      2003-11-03    2003-11-15  First_cat1    F_cat2
# 3            6585      2003-11-22    2003-12-05  First_cat1    E_cat2
# 4            6561      2003-11-30    2003-12-18  First_cat1    E_cat2
#
#   Category3  Camp_duration  Camp_start_Day  Camp_start_Month  Camp_start_Year  \
# 0    2_cat3            4.0               5                 8             2003
# 1    2_cat3           73.0               5                 8             2003
# 2    1_cat3           12.0               0                11             2003
# 3    2_cat3           13.0               5                11             2003
# 4    1_cat3           18.0               6                11             2003
#
#    Camp_End_Day  Camp_End_Month  Camp_End_Year  weekends_during_campaign
# ...

# %%
hcd=pd.get_dummies(hcd,columns=['Category1','Category2','Category3'],drop_first=True)

# %%
hcd.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date  Camp_duration  \
# 0            6560      2003-08-16    2003-08-20            4.0
# 1            6530      2003-08-16    2003-10-28           73.0
# 2            6544      2003-11-03    2003-11-15           12.0
# 3            6585      2003-11-22    2003-12-05           13.0
# 4            6561      2003-11-30    2003-12-18           18.0
#
#    Camp_start_Day  Camp_start_Month  Camp_start_Year  Camp_End_Day  \
# 0               5                 8             2003             2
# 1               5                 8             2003             1
# 2               0                11             2003             5
# 3               5                11             2003             4
# 4               6                11             2003             3
#
#    Camp_End_Month  Camp_End_Year  weekends_during_campaign  \
# 0               8           2003                         2
# 1              10           2003                        22
# ...

# %%
sns.countplot(hcd['Camp_start_Month'])
# Out:
# <AxesSubplot:xlabel='Camp_start_Month', ylabel='count'>

# %%
# in 8th month no of health camps

# %%
sns.boxplot(hcd['Camp_duration'])
# Out:
# <AxesSubplot:xlabel='Camp_duration'>

# %%
patient=pd.read_csv("Patient_Details.csv")
patient.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income Education_Score Age First_Interaction City_Type  \
# 0                0      1              90  39         18-Jun-03       NaN
# 1                0      1            None  40         20-Jul-03         H
# 2                0      3              87  46         02-Nov-02         D
# 3                0      1              75  47         02-Nov-02         D
# 4                0      3            None  80         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# 3          Education
# 4             Others

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37633 entries, 0 to 37632
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         37633 non-null  int64
#  1   Online_Follower    37633 non-null  int64
#  2   LinkedIn_Shared    37633 non-null  int64
#  3   Twitter_Shared     37633 non-null  int64
#  4   Facebook_Shared    37633 non-null  int64
#  5   Income             37633 non-null  object
#  6   Education_Score    37633 non-null  object
#  7   Age                37633 non-null  object
#  8   First_Interaction  37633 non-null  object
#  9   City_Type          14249 non-null  object
#  10  Employer_Category  2840 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 3.2+ MB

# %%
patient['First_Interaction']=pd.to_datetime(patient['First_Interaction'])

# %%
patient['First_Interaction_day']=patient['First_Interaction'].apply(lambda x:x.dayofweek)
patient['First_Interaction_month']=patient['First_Interaction'].apply(lambda x:x.month)
patient['First_Interaction_year']=patient['First_Interaction'].apply(lambda x:x.year)

# %%
patient.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income Education_Score Age First_Interaction City_Type  \
# 0                0      1              90  39        2003-06-18       NaN
# 1                0      1            None  40        2003-07-20         H
# 2                0      3              87  46        2002-11-02         D
# 3                0      1              75  47        2002-11-02         D
# 4                0      3            None  80        2002-11-24         H
#
#    Employer_Category  First_Interaction_day  First_Interaction_month  \
# ...

# %%
patient['Education_Score']=patient['Education_Score'].replace('None',np.nan)

# %%
patient['Education_Score']=patient['Education_Score'].astype('float')

# %%
patient['Age']=patient['Age'].replace('None',np.nan)

# %%
patient['Age']=pd.to_numeric(patient['Age'])

# %%
patient.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income  Education_Score   Age First_Interaction City_Type  \
# 0                0      1             90.0  39.0        2003-06-18       NaN
# 1                0      1              NaN  40.0        2003-07-20         H
# 2                0      3             87.0  46.0        2002-11-02         D
# 3                0      1             75.0  47.0        2002-11-02         D
# 4                0      3              NaN  80.0        2002-11-24         H
#
#    Employer_Category  First_Interaction_day  First_Interaction_month  \
# ...

# %%
patient['Online_Follower'].value_counts()
# Out:
# 0    36785
# 1      848
# Name: Online_Follower, dtype: int64

# %%
patient['LinkedIn_Shared'].value_counts()
# Out:
# 0    36614
# 1     1019
# Name: LinkedIn_Shared, dtype: int64

# %%
patient['Twitter_Shared'].value_counts()
# Out:
# 0    36820
# 1      813
# Name: Twitter_Shared, dtype: int64

# %%
patient['Facebook_Shared'].value_counts()
# Out:
# 0    36747
# 1      886
# Name: Facebook_Shared, dtype: int64

# %%
patient['Social_media_effect']=patient['Online_Follower']+patient['LinkedIn_Shared']+patient['Facebook_Shared']+patient['Twitter_Shared']

# %%
patient['Social_media_effect'].value_counts()
# Out:
# 0    35943
# 2      579
# 1      538
# 3      422
# 4      151
# Name: Social_media_effect, dtype: int64

# %%
patient.drop(['Online_Follower','LinkedIn_Shared','Facebook_Shared','Twitter_Shared'],axis=1,inplace=True)

# %%
patient['Income'].value_counts()
# Out:
# None    33271
# 0        2033
# 1        1013
# 2         685
# 3         362
# 4         156
# 5          70
# 6          43
# Name: Income, dtype: int64

# %%
patient['City_Type']=patient['City_Type'].fillna('None')

# %%
patient['City_Type'].value_counts()
# Out:
# None    23384
# B        2662
# H        2517
# A        1729
# D        1704
# G        1352
# E        1217
# C        1216
# I        1036
# F         816
# Name: City_Type, dtype: int64

# %%
patient['Employer_Category'].unique()
# Out:
# array(['Software Industry', 'BFSI', 'Education', 'Others', nan,
#        'Technology', 'Consulting', 'Manufacturing', 'Health', 'Retail',
#        'Transport', 'Broadcasting', 'Food', 'Telecom', 'Real Estate'],
#       dtype=object)

# %%
patient=pd.get_dummies(patient,columns=['Income','City_Type'],drop_first=True)

# %%
patient.head()
# Out:
#    Patient_ID  Education_Score   Age First_Interaction  Employer_Category  \
# 0      516956             90.0  39.0        2003-06-18  Software Industry
# 1      507733              NaN  40.0        2003-07-20  Software Industry
# 2      508307             87.0  46.0        2002-11-02               BFSI
# 3      512612             75.0  47.0        2002-11-02          Education
# 4      521075              NaN  80.0        2002-11-24             Others
#
#    First_Interaction_day  First_Interaction_month  First_Interaction_year  \
# 0                      2                        6                    2003
# 1                      6                        7                    2003
# 2                      5                       11                    2002
# 3                      5                       11                    2002
# 4                      6                       11                    2002
#
# ...

# %%
patient.shape
# Out:
# (37633, 25)

# %%
patient['Employer_Category'].unique()
# Out:
# array(['Software Industry', 'BFSI', 'Education', 'Others', nan,
#        'Technology', 'Consulting', 'Manufacturing', 'Health', 'Retail',
#        'Transport', 'Broadcasting', 'Food', 'Telecom', 'Real Estate'],
#       dtype=object)

# %%
sns.distplot(patient['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(patient['Education_Score'])
# Out:
# <AxesSubplot:xlabel='Education_Score', ylabel='Density'>

# %%
fhc=pd.read_csv("First_Health_Camp.csv")
fhc.head()
# Out:
#    Patient_ID  Health_Camp_ID  Donation  Health_Score
# 0      506181            6560        40      0.439024
# 1      494977            6560        20      0.097561
# 2      518680            6560        10      0.048780
# 3      509916            6560        30      0.634146
# 4      488006            6560        20      0.024390

# %%
fhc.isnull().sum()
# Out:
# Patient_ID        0
# Health_Camp_ID    0
# Donation          0
# Health_Score      0
# dtype: int64

# %%
shc=pd.read_csv("Second_Health_Camp.csv")
shc.head()
# Out:
#    Patient_ID  Health_Camp_ID  Health Score
# 0      526631            6536      0.875136
# 1      509122            6536      0.755700
# 2      498864            6536      0.673181
# 3      515398            6536      0.722041
# 4      504624            6536      0.464712

# %%
shc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7819 entries, 0 to 7818
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      7819 non-null   int64
#  1   Health_Camp_ID  7819 non-null   int64
#  2   Health Score    7819 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 183.4 KB

# %%
thc=pd.read_csv("Third_Health_Camp.csv")
thc.head()
# Out:
#    Patient_ID  Health_Camp_ID  Number_of_stall_visited  \
# 0      517875            6527                        3
# 1      504692            6578                        1
# 2      504692            6527                        3
# 3      493167            6527                        4
# 4      510954            6528                        2
#
#    Last_Stall_Visited_Number
# 0                          1
# 1                          1
# 2                          1
# 3                          4
# 4                          2

# %%
thc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6515 entries, 0 to 6514
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient_ID                 6515 non-null   int64
#  1   Health_Camp_ID             6515 non-null   int64
#  2   Number_of_stall_visited    6515 non-null   int64
#  3   Last_Stall_Visited_Number  6515 non-null   int64
# dtypes: int64(4)
# memory usage: 203.7 KB

# %%
train=pd.read_csv("train.csv")
train.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      526927            6570          14/05/05     0     0     0     0     0
# 1      510379            6534          26/05/06     0     0     0     0     0
# 2      520968            6557          07/01/04     0     0     0     0     0
# 3      507625            6535          12/02/04     0     0     0     0     0
# 4      502611            6581          14/03/04     0     0     0     0     0
#
#    outcome
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52694 entries, 0 to 52693
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         52694 non-null  int64
#  1   Health_Camp_ID     52694 non-null  int64
#  2   Registration_Date  52463 non-null  object
#  3   Var1               52694 non-null  int64
#  4   Var2               52694 non-null  int64
#  5   Var3               52694 non-null  int64
#  6   Var4               52694 non-null  int64
#  7   Var5               52694 non-null  int64
#  8   outcome            52694 non-null  int64
# dtypes: int64(8), object(1)
# memory usage: 3.6+ MB

# %%
train.isnull().sum()
# Out:
# Patient_ID             0
# Health_Camp_ID         0
# Registration_Date    231
# Var1                   0
# Var2                   0
# Var3                   0
# Var4                   0
# Var5                   0
# outcome                0
# dtype: int64

# %%
train=train.dropna()

# %%
train.isnull().sum()
# Out:
# Patient_ID           0
# Health_Camp_ID       0
# Registration_Date    0
# Var1                 0
# Var2                 0
# Var3                 0
# Var4                 0
# Var5                 0
# outcome              0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52463 entries, 0 to 52693
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         52463 non-null  int64
#  1   Health_Camp_ID     52463 non-null  int64
#  2   Registration_Date  52463 non-null  object
#  3   Var1               52463 non-null  int64
#  4   Var2               52463 non-null  int64
#  5   Var3               52463 non-null  int64
#  6   Var4               52463 non-null  int64
#  7   Var5               52463 non-null  int64
#  8   outcome            52463 non-null  int64
# dtypes: int64(8), object(1)
# memory usage: 4.0+ MB

# %%
train['Registration_Date']=pd.to_datetime(train['Registration_Date'])

# %%
test=pd.read_csv("Test.csv")
test.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5
# 0      507518            6529          02/04/06     0     0     0     0     0
# 1      516180            6570          13/05/05     0     0     0     0     0
# 2      507204            6537          16/01/07     0     0     0     0     0
# 3      505815            6578          27/07/05     0     0     0     0     0
# 4      501809            6542          22/07/05     0     0     0     0     0

# %%
test['Registration_Date']=pd.to_datetime(test['Registration_Date'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52463 entries, 0 to 52693
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         52463 non-null  int64
#  1   Health_Camp_ID     52463 non-null  int64
#  2   Registration_Date  52463 non-null  datetime64[ns]
#  3   Var1               52463 non-null  int64
#  4   Var2               52463 non-null  int64
#  5   Var3               52463 non-null  int64
#  6   Var4               52463 non-null  int64
#  7   Var5               52463 non-null  int64
#  8   outcome            52463 non-null  int64
# dtypes: datetime64[ns](1), int64(8)
# memory usage: 4.0 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22584 entries, 0 to 22583
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         22584 non-null  int64
#  1   Health_Camp_ID     22584 non-null  int64
#  2   Registration_Date  22481 non-null  datetime64[ns]
#  3   Var1               22584 non-null  int64
#  4   Var2               22584 non-null  int64
#  5   Var3               22584 non-null  int64
#  6   Var4               22584 non-null  int64
#  7   Var5               22584 non-null  int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 1.4 MB

# %%
train['Registration_Date_day']=train['Registration_Date'].apply(lambda x:x.dayofweek)

# %%
test['Registration_Date_day']=test['Registration_Date'].apply(lambda x:x.dayofweek)

# %%
train['Registration_Date_month']=train['Registration_Date'].apply(lambda x:x.month)
test['Registration_Date_month']=test['Registration_Date'].apply(lambda x:x.month)

# %%
train['Registration_Date_Year']=train['Registration_Date'].apply(lambda x:x.year)
test['Registration_Date_Year']=test['Registration_Date'].apply(lambda x:x.year)

# %%
train.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      526927            6570        2005-05-14     0     0     0     0     0
# 1      510379            6534        2006-05-26     0     0     0     0     0
# 2      520968            6557        2004-07-01     0     0     0     0     0
# 3      507625            6535        2004-12-02     0     0     0     0     0
# 4      502611            6581        2004-03-14     0     0     0     0     0
#
#    outcome  Registration_Date_day  Registration_Date_month  \
# 0        0                      5                        5
# 1        1                      4                        5
# 2        1                      3                        7
# 3        0                      3                       12
# 4        0                      6                        3
#
#    Registration_Date_Year
# 0                    2005
# 1                    2006
# 2                    2004
# 3                    2004
# ...

# %%
test.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      507518            6529        2006-02-04     0     0     0     0     0
# 1      516180            6570        2005-05-13     0     0     0     0     0
# 2      507204            6537        2007-01-16     0     0     0     0     0
# 3      505815            6578        2005-07-27     0     0     0     0     0
# 4      501809            6542        2005-07-22     0     0     0     0     0
#
#    Registration_Date_day  Registration_Date_month  Registration_Date_Year
# 0                    5.0                      2.0                  2006.0
# 1                    4.0                      5.0                  2005.0
# 2                    1.0                      1.0                  2007.0
# 3                    2.0                      7.0                  2005.0
# 4                    4.0                      7.0                  2005.0

# %%
test['Registration_Date'].mode()
# Out:
# 0   2006-03-28
# dtype: datetime64[ns]

# %%
test['Registration_Date']=test['Registration_Date'].fillna('2006-03-28')

# %%
test.isnull().sum()
# Out:
# Patient_ID            0
# Health_Camp_ID        0
# Registration_Date     0
# Var1                  0
# Var2                  0
#                      ..
# regis_fi              0
# fi_cs                 0
# fi_ce                 0
# nos_hc_per_patient    0
# nos_pat_per_health    0
# Length: 61, dtype: int64

# %%
train=pd.merge(train,hcd,how='left')

# %%
train.shape
# Out:
# (52463, 31)

# %%
test=pd.merge(test,hcd,how='left')

# %%
test.shape
# Out:
# (22584, 30)

# %%
train=pd.merge(train,patient,how='left')

# %%
test=pd.merge(test,patient,how='left')

# %%
train = pd.merge(train, fhc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])

# %%
test = pd.merge(test, fhc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])

# %%
train = pd.merge(train, shc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])
test = pd.merge(test, shc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])

# %%
train = pd.merge(train, thc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])
test = pd.merge(test, thc,  how='left', left_on=['Patient_ID','Health_Camp_ID'], right_on = ['Patient_ID','Health_Camp_ID'])

# %%
train.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      526927            6570        2005-05-14     0     0     0     0     0
# 1      510379            6534        2006-05-26     0     0     0     0     0
# 2      520968            6557        2004-07-01     0     0     0     0     0
# 3      507625            6535        2004-12-02     0     0     0     0     0
# 4      502611            6581        2004-03-14     0     0     0     0     0
#
#    outcome  Registration_Date_day  ...  City_Type_F  City_Type_G City_Type_H  \
# 0        0                      5  ...            0            0           0
# 1        1                      4  ...            0            0           1
# 2        1                      3  ...            0            0           1
# 3        0                      3  ...            0            0           0
# 4        0                      6  ...            0            0           0
#
# ...

# %%
test.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      507518            6529        2006-02-04     0     0     0     0     0
# 1      516180            6570        2005-05-13     0     0     0     0     0
# 2      507204            6537        2007-01-16     0     0     0     0     0
# 3      505815            6578        2005-07-27     0     0     0     0     0
# 4      501809            6542        2005-07-22     0     0     0     0     0
#
#    Registration_Date_day  Registration_Date_month  ...  City_Type_F  \
# 0                    5.0                      2.0  ...            0
# 1                    4.0                      5.0  ...            0
# 2                    1.0                      1.0  ...            0
# 3                    2.0                      7.0  ...            0
# 4                    4.0                      7.0  ...            0
#
#   City_Type_G City_Type_H  City_Type_I  City_Type_None  Donation  \
# ...

# %%
train.shape
# Out:
# (52463, 60)

# %%
test.shape
# Out:
# (22584, 59)

# %%
train.isnull().sum()
# Out:
# Patient_ID                       0
# Health_Camp_ID                   0
# Registration_Date                0
# Var1                             0
# Var2                             0
# Var3                             0
# Var4                             0
# Var5                             0
# outcome                          0
# Registration_Date_day            0
# Registration_Date_month          0
# Registration_Date_Year           0
# Camp_Start_Date                  0
# Camp_End_Date                    0
# Camp_duration                    0
# Camp_start_Day                   0
# Camp_start_Month                 0
# Camp_start_Year                  0
# Camp_End_Day                     0
# Camp_End_Month                   0
# Camp_End_Year                    0
# weekends_during_campaign         0
# Category1_Second_cat1            0
# Category1_Third_cat1             0
# Category2_B_cat2                 0
# Category2_C_cat2                 0
# Category2_D_cat2                 0
# ...

# %%
test.isnull().sum()
# Out:
# Patient_ID                       0
# Health_Camp_ID                   0
# Registration_Date                0
# Var1                             0
# Var2                             0
# Var3                             0
# Var4                             0
# Var5                             0
# Registration_Date_day          103
# Registration_Date_month        103
# Registration_Date_Year         103
# Camp_Start_Date                  0
# Camp_End_Date                    0
# Camp_duration                    0
# Camp_start_Day                   0
# Camp_start_Month                 0
# Camp_start_Year                  0
# Camp_End_Day                     0
# Camp_End_Month                   0
# Camp_End_Year                    0
# weekends_during_campaign         0
# Category1_Second_cat1            0
# Category1_Third_cat1             0
# Category2_B_cat2                 0
# Category2_C_cat2                 0
# Category2_D_cat2                 0
# Category2_E_cat2                 0
# ...

# %%
train.drop(['Donation','Health_Score','Health Score','Number_of_stall_visited','Last_Stall_Visited_Number'],axis=1,inplace=True)

# %%
test.drop(['Donation','Health_Score','Health Score','Number_of_stall_visited','Last_Stall_Visited_Number'],axis=1,inplace=True)

# %%
train.isnull().sum()
# Out:
# Patient_ID                      0
# Health_Camp_ID                  0
# Registration_Date               0
# Var1                            0
# Var2                            0
# Var3                            0
# Var4                            0
# Var5                            0
# outcome                         0
# Registration_Date_day           0
# Registration_Date_month         0
# Registration_Date_Year          0
# Camp_Start_Date                 0
# Camp_End_Date                   0
# Camp_duration                   0
# Camp_start_Day                  0
# Camp_start_Month                0
# Camp_start_Year                 0
# Camp_End_Day                    0
# Camp_End_Month                  0
# Camp_End_Year                   0
# weekends_during_campaign        0
# Category1_Second_cat1           0
# Category1_Third_cat1            0
# Category2_B_cat2                0
# Category2_C_cat2                0
# Category2_D_cat2                0
# ...

# %%
train_avg_edu=train['Education_Score'].mean()
train_avg_age=train['Age'].mean()
train['Education_Score']=train['Education_Score'].fillna(train_avg_edu)
train['Age']=train['Age'].fillna(train_avg_age)

# %%
train.isnull().sum()
# Out:
# Patient_ID                      0
# Health_Camp_ID                  0
# Registration_Date               0
# Var1                            0
# Var2                            0
# Var3                            0
# Var4                            0
# Var5                            0
# outcome                         0
# Registration_Date_day           0
# Registration_Date_month         0
# Registration_Date_Year          0
# Camp_Start_Date                 0
# Camp_End_Date                   0
# Camp_duration                   0
# Camp_start_Day                  0
# Camp_start_Month                0
# Camp_start_Year                 0
# Camp_End_Day                    0
# Camp_End_Month                  0
# Camp_End_Year                   0
# weekends_during_campaign        0
# Category1_Second_cat1           0
# Category1_Third_cat1            0
# Category2_B_cat2                0
# Category2_C_cat2                0
# Category2_D_cat2                0
# ...

# %%
test_avg_edu=test['Education_Score'].mean()
test_avg_age=test['Age'].mean()
test['Education_Score']=test['Education_Score'].fillna(test_avg_edu)
test['Age']=test['Age'].fillna(test_avg_age)

# %%
test.isnull().sum()
# Out:
# Patient_ID                      0
# Health_Camp_ID                  0
# Registration_Date               0
# Var1                            0
# Var2                            0
# Var3                            0
# Var4                            0
# Var5                            0
# Registration_Date_day         103
# Registration_Date_month       103
# Registration_Date_Year        103
# Camp_Start_Date                 0
# Camp_End_Date                   0
# Camp_duration                   0
# Camp_start_Day                  0
# Camp_start_Month                0
# Camp_start_Year                 0
# Camp_End_Day                    0
# Camp_End_Month                  0
# Camp_End_Year                   0
# weekends_during_campaign        0
# Category1_Second_cat1           0
# Category1_Third_cat1            0
# Category2_B_cat2                0
# Category2_C_cat2                0
# Category2_D_cat2                0
# Category2_E_cat2                0
# ...

# %%
train.shape
# Out:
# (52463, 55)

# %%
test.shape
# Out:
# (22584, 54)

# %%
sns.scatterplot(x='Age',y='Education_Score',data=train,hue='outcome')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Education_Score'>

# %%
#Camp_Start_Date, Camp_End_Date, Registration_Date, First_Interaction
train['regis_cs']=(train['Camp_Start_Date']-train['Registration_Date']).astype('timedelta64[D]')
train['regis_ce']=(train['Camp_End_Date']-train['Registration_Date']).astype('timedelta64[D]')
train['regis_fi']=(train['Registration_Date']-train['First_Interaction']).astype('timedelta64[D]')

test['regis_cs']=(test['Camp_Start_Date']-test['Registration_Date']).astype('timedelta64[D]')
test['regis_ce']=(test['Camp_End_Date']-test['Registration_Date']).astype('timedelta64[D]')
test['regis_fi']=(test['Registration_Date']-test['First_Interaction']).astype('timedelta64[D]')

train['fi_cs']=(train['Camp_Start_Date']-train['First_Interaction']).astype('timedelta64[D]')
train['fi_ce']=(train['Camp_End_Date']-train['First_Interaction']).astype('timedelta64[D]')

test['fi_cs']=(test['Camp_Start_Date']-test['First_Interaction']).astype('timedelta64[D]')
test['fi_ce']=(test['Camp_End_Date']-test['First_Interaction']).astype('timedelta64[D]')

# %%
train.shape
# Out:
# (52463, 60)

# %%
train['nos_hc_per_patient']=train.groupby('Patient_ID')['Health_Camp_ID'].transform('nunique')
train['nos_pat_per_health']=train.groupby('Health_Camp_ID')['Patient_ID'].transform('nunique')

test['nos_hc_per_patient']=test.groupby('Patient_ID')['Health_Camp_ID'].transform('nunique')
test['nos_pat_per_health']=test.groupby('Health_Camp_ID')['Patient_ID'].transform('nunique')

# %%
train.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      526927            6570        2005-05-14     0     0     0     0     0
# 1      510379            6534        2006-05-26     0     0     0     0     0
# 2      520968            6557        2004-07-01     0     0     0     0     0
# 3      507625            6535        2004-12-02     0     0     0     0     0
# 4      502611            6581        2004-03-14     0     0     0     0     0
#
#    outcome  Registration_Date_day  ...  City_Type_H  City_Type_I  \
# 0        0                      5  ...            0            0
# 1        1                      4  ...            1            0
# 2        1                      3  ...            1            0
# 3        0                      3  ...            0            0
# 4        0                      6  ...            0            0
#
#   City_Type_None regis_cs  regis_ce  regis_fi  fi_cs  fi_ce  \
# ...

# %%
corr_train=train.drop(['Registration_Date','Camp_Start_Date','Camp_End_Date','Patient_ID','Health_Camp_ID','First_Interaction','Employer_Category'],axis=1).corr()
corr_train.reset_index(inplace=True)
corr_train=corr_train[['index','outcome']]
corr_train['outcome']=corr_train['outcome'].apply(lambda x:abs(x))
corr_train.sort_values(by='outcome',ascending=False,inplace=True)

# %%
corr_train
# Out:
#                        index   outcome
# 5                    outcome  1.000000
# 18      Category1_Third_cat1  0.321217
# 24          Category2_G_cat2  0.321217
# 17     Category1_Second_cat1  0.273259
# 22          Category2_E_cat2  0.235138
# 23          Category2_F_cat2  0.233823
# 12           Camp_start_Year  0.225478
# 8     Registration_Date_Year  0.175288
# 21          Category2_D_cat2  0.156507
# 10            Camp_start_Day  0.146842
# 53        nos_hc_per_patient  0.116717
# 13              Camp_End_Day  0.116309
# 47            City_Type_None  0.115568
# 51                     fi_cs  0.115484
# 50                  regis_fi  0.102256
# 15             Camp_End_Year  0.098721
# 38               Income_None  0.086951
# 52                     fi_ce  0.081853
# 7    Registration_Date_month  0.073636
# 54        nos_pat_per_health  0.071554
# 14            Camp_End_Month  0.068347
# 4                       Var5  0.063222
# 31       Social_media_effect  0.062423
# ...

# %%
independent_variables=corr_train.iloc[1:len(corr_train)//2]['index'] #taking 50% of variables
independent_variables
# Out:
# 18       Category1_Third_cat1
# 24           Category2_G_cat2
# 17      Category1_Second_cat1
# 22           Category2_E_cat2
# 23           Category2_F_cat2
# 12            Camp_start_Year
# 8      Registration_Date_Year
# 21           Category2_D_cat2
# 10             Camp_start_Day
# 53         nos_hc_per_patient
# 13               Camp_End_Day
# 47             City_Type_None
# 51                      fi_cs
# 50                   regis_fi
# 15              Camp_End_Year
# 38                Income_None
# 52                      fi_ce
# 7     Registration_Date_month
# 54         nos_pat_per_health
# 14             Camp_End_Month
# 4                        Var5
# 31        Social_media_effect
# 30     First_Interaction_year
# 19           Category2_B_cat2
# 11           Camp_start_Month
# 32                   Income_1
# Name: index, dtype: object

# %%
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = [independent_variables.iloc[i] for i in range(len(independent_variables))]
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(train[independent_variables].dropna())
# Out:
# C:\Users\Vishal Aggarwal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                   variables           VIF
# 0      Category1_Third_cat1           inf
# 1          Category2_G_cat2           inf
# 2     Category1_Second_cat1  1.133549e+01
# 3          Category2_E_cat2  1.572072e+01
# 4          Category2_F_cat2  1.920230e+01
# 5           Camp_start_Year  8.445426e+09
# 6    Registration_Date_Year  6.108916e+09
# 7          Category2_D_cat2  1.827354e+00
# 8            Camp_start_Day  7.191667e+00
# 9        nos_hc_per_patient  3.997521e+00
# 10             Camp_End_Day  6.265573e+00
# 11           City_Type_None  2.532488e+00
# 12                    fi_cs  1.686207e+03
# 13                 regis_fi  1.396945e+03
# 14            Camp_End_Year  7.072263e+09
# 15              Income_None  6.924902e+00
# 16                    fi_ce  3.135464e+03
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from  sklearn.ensemble import RandomForestClassifier

# %%
train.shape
# Out:
# (52463, 62)

# %%
xtrain=train[independent_variables]

# %%
ytrain=train['outcome']

# %%
xtest=test[independent_variables]

# %%
xtrain.shape
# Out:
# (52463, 26)

# %%
ytrain.shape
# Out:
# (52463,)

# %%
xtest.shape
# Out:
# (22584, 26)

# %%
train[independent_variables]
# Out:
#        Category1_Third_cat1  Category2_G_cat2  Category1_Second_cat1  \
# 0                         0                 0                      0
# 1                         0                 0                      1
# 2                         0                 0                      0
# 3                         0                 0                      0
# 4                         0                 0                      0
# ...                     ...               ...                    ...
# 52458                     0                 0                      1
# 52459                     0                 0                      0
# 52460                     0                 0                      1
# 52461                     0                 0                      1
# 52462                     0                 0                      0
#
#        Category2_E_cat2  Category2_F_cat2  Camp_start_Year  \
# 0                     1                 0             2005
# ...

# %%
rf_classification = RandomForestClassifier(n_estimators = 10, random_state = 10)

# use fit() to fit the model on the train set
rf_model = rf_classification.fit(xtrain, ytrain)

# %%
from sklearn.metrics import classification_report

# %%
train_report = get_train_report(rf_model)

# print the performace measures
print(train_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     38261
#            1       0.97      0.92      0.94     14202
#
#     accuracy                           0.97     52463
#    macro avg       0.97      0.95      0.96     52463
# weighted avg       0.97      0.97      0.97     52463

# %%
def get_train_report(model):
    
    # for training set:
    # train_pred: prediction made by the model on the train dataset 'X_train'
    # y_train: actual values of the target variable for the train dataset

    # predict the output of the target variable from the train data 
    train_pred = model.predict(xtrain)

    # return the performace measures on train set
    return(classification_report(ytrain, train_pred))

# %%
xtest.isnull().sum()
# Out:
# Category1_Third_cat1       0
# Category2_G_cat2           0
# Category1_Second_cat1      0
# Category2_E_cat2           0
# Category2_F_cat2           0
# Camp_start_Year            0
# Registration_Date_Year     0
# Category2_D_cat2           0
# Camp_start_Day             0
# nos_hc_per_patient         0
# Camp_End_Day               0
# City_Type_None             0
# fi_cs                      0
# regis_fi                   0
# Camp_End_Year              0
# Income_None                0
# fi_ce                      0
# Registration_Date_month    0
# nos_pat_per_health         0
# Camp_End_Month             0
# Var5                       0
# Social_media_effect        0
# First_Interaction_year     0
# Category2_B_cat2           0
# Camp_start_Month           0
# Income_1                   0
# dtype: int64

# %%
test_pred = rf_model.predict(xtest)

# %%
pred=pd.Series(test_pred)

# %%
test['outcome']=pred

# %%
test.to_csv("abc.csv",index='False')

# %%
tuned_paramaters = [{'criterion': ['entropy', 'gini'],
                     'n_estimators': [10, 30, 50, 70, 90],
                     'max_depth': [10, 15, 20],
                     'max_features': ['sqrt', 'log2'],
                     'min_samples_split': [2, 5, 8, 11],
                     'min_samples_leaf': [1, 5, 9],
                     'max_leaf_nodes': [2, 5, 8, 11]}]

# %%
random_forest_classification = RandomForestClassifier(random_state = 7)

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_grid = GridSearchCV(estimator = random_forest_classification, 
                       param_grid = tuned_paramaters, 
                       cv = 5)
rf_grid_model = rf_grid.fit(xtrain, ytrain)

print('Best parameters for random forest classifier: ', rf_grid_model.best_params_, '\n')

# %%
# pass the 'random_state' to obtain the same samples for each time you run the code
rf_model = RandomForestClassifier(criterion = rf_grid_model.best_params_.get('criterion'), 
                                  n_estimators = rf_grid_model.best_params_.get('n_estimators'),
                                  max_depth = rf_grid_model.best_params_.get('max_depth'),
                                  max_features = rf_grid_model.best_params_.get('max_features'),
                                  max_leaf_nodes = rf_grid_model.best_params_.get('max_leaf_nodes'),
                                  min_samples_leaf = rf_grid_model.best_params_.get('min_samples_leaf'),
                                  min_samples_split = rf_grid_model.best_params_.get('min_samples_split'),
                                  random_state = 7)

# use fit() to fit the model on the train set
rf_model = rf_model.fit(xtrain, ytrain)

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb

# %%
from lightgbm import LGBMClassifier

# %%
model = LGBMClassifier(random_state=5)
model.fit(xtrain, ytrain)
# Out:
# LGBMClassifier(random_state=5)

# %%
preds=model.predict(xtest)

# %%
pred=pd.Series(preds)

# %%
test['outcome']=pred

# %%
test.to_csv("xyz_mri.csv",index='False')
